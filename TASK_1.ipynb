# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\hp\OneDrive\Documents\PRODIGY INFOTECH\bank-additional.csv",sep=';')
df.head(2)
# Out:
#    age          job  marital    education default housing loan    contact  \
# 0   30  blue-collar  married     basic.9y      no     yes   no   cellular
# 1   39     services   single  high.school      no      no   no  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         fri  ...         2    999         0  nonexistent         -1.8
# 1   may         fri  ...         4    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.313       5099.1  no
# 1          93.994          -36.4      4.855       5191.0  no
#
# [2 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4119 non-null   int64
#  1   job             4119 non-null   object
#  2   marital         4119 non-null   object
#  3   education       4119 non-null   object
#  4   default         4119 non-null   object
#  5   housing         4119 non-null   object
#  6   loan            4119 non-null   object
#  7   contact         4119 non-null   object
#  8   month           4119 non-null   object
#  9   day_of_week     4119 non-null   object
#  10  duration        4119 non-null   int64
#  11  campaign        4119 non-null   int64
#  12  pdays           4119 non-null   int64
#  13  previous        4119 non-null   int64
#  14  poutcome        4119 non-null   object
#  15  emp.var.rate    4119 non-null   float64
#  16  cons.price.idx  4119 non-null   float64
# ...

# %%
df.shape
# Out:
# (4119, 21)

# %%
df.describe()
# Out:
#                age     duration     campaign        pdays     previous  \
# count  4119.000000  4119.000000  4119.000000  4119.000000  4119.000000
# mean     40.113620   256.788055     2.537266   960.422190     0.190337
# std      10.313362   254.703736     2.568159   191.922786     0.541788
# min      18.000000     0.000000     1.000000     0.000000     0.000000
# 25%      32.000000   103.000000     1.000000   999.000000     0.000000
# 50%      38.000000   181.000000     2.000000   999.000000     0.000000
# 75%      47.000000   317.000000     3.000000   999.000000     0.000000
# max      88.000000  3643.000000    35.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count   4119.000000     4119.000000    4119.000000  4119.000000  4119.000000
# mean       0.084972       93.579704     -40.499102     3.621356  5166.481695
# std        1.563114        0.579349       4.594578     1.733591    73.667904
# ...

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'day_of_week', 'poutcome', 'y'],
#       dtype='object')

# %%
df['job'].unique()
# Out:
# array(['blue-collar', 'services', 'admin.', 'entrepreneur',
#        'self-employed', 'technician', 'management', 'student', 'retired',
#        'housemaid', 'unemployed', 'unknown'], dtype=object)

# %%
df['job'].nunique()
# Out:
# 12

# %%
df['job'].value_counts()
# Out:
# admin.           1012
# blue-collar       884
# technician        691
# services          393
# management        324
# retired           166
# self-employed     159
# entrepreneur      148
# unemployed        111
# housemaid         110
# student            82
# unknown            39
# Name: job, dtype: int64

# %%
unique_cnt=df['job'].unique()
count_list=[]
for i in unique_cnt:
    con=df['job']==i
    val=len(df[con])
    count_list.append(val)

# %%
job_df=pd.DataFrame(zip(unique_cnt,count_list),columns=['JOB','COUNT'])
job_df
# Out:
#               JOB  COUNT
# 0     blue-collar    884
# 1        services    393
# 2          admin.   1012
# 3    entrepreneur    148
# 4   self-employed    159
# 5      technician    691
# 6      management    324
# 7         student     82
# 8         retired    166
# 9       housemaid    110
# 10     unemployed    111
# 11        unknown     39

# %%
unique_cnt=df['education'].unique()
count_list=[]
for i in unique_cnt:
    con=df['education']==i
    val=len(df[con])
    count_list.append(val)

# %%
education_df=pd.DataFrame(zip(unique_cnt,count_list),columns=['EDUCATION','COUNT1'])
education_df
# Out:
#              EDUCATION  COUNT1
# 0             basic.9y     574
# 1          high.school     921
# 2    university.degree    1264
# 3  professional.course     535
# 4             basic.6y     228
# 5             basic.4y     429
# 6              unknown     167
# 7           illiterate       1

# %%
unique_cnt=df['contact'].unique()
count_list=[]
for i in unique_cnt:
    con=df['contact']==i
    val=len(df[con])
    count_list.append(val)

# %%
contact_df=pd.DataFrame(zip(unique_cnt,count_list),columns=['CONTACT TYPE','USERS'])
contact_df
# Out:
#   CONTACT TYPE  USERS
# 0     cellular   2652
# 1    telephone   1467

# %%
unique_cnt=df['marital'].unique()
count_list=[]
for i in unique_cnt:
    con=df['marital']==i
    val=len(df[con])
    count_list.append(val)

# %%
marital_df=pd.DataFrame(zip(unique_cnt,count_list),columns=['MARITAL STATUS','PEOPLE'])
marital_df
# Out:
#   MARITAL STATUS  PEOPLE
# 0        married    2509
# 1         single    1153
# 2       divorced     446
# 3        unknown      11

# %%
unique_cnt=df['poutcome'].unique()
count_list=[]
for i in unique_cnt:
    con=df['poutcome']==i
    val=len(df[con])
    count_list.append(val)
    
poutcome_df=pd.DataFrame(zip(unique_cnt,count_list),columns=['POUTCOME','STATUS'])
poutcome_df
# Out:
#       POUTCOME  STATUS
# 0  nonexistent    3523
# 1      failure     454
# 2      success     142

# %% [markdown]
# **BAR CHART**
#
# - Here We plot BarChart with two columns :
#
#     - JOB
#
#     - COUNT
#
# - It Will give visualization of data distributed over different jobs

# %%
plt.figure(figsize=(16,6))
plt.bar('JOB','COUNT',data=job_df,label="JOB")
plt.title("BAR CHART - COUNT OF DIFFERENT CATEGORY JOBS")
plt.xlabel("JOB NAMES")
plt.ylabel("COUNT OF PEOPLE")
plt.legend(['JOB'])
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.bar('EDUCATION','COUNT1',data=education_df)
plt.title("BAR CHART - EDUCATION")
plt.xlabel("EDUCATION")
plt.ylabel("COUNT OF PEOPLE")
plt.legend(['EDUCATION'])
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.bar('CONTACT TYPE','USERS',data=contact_df)
plt.title("BAR CHART - CONTACT")
plt.xlabel("CONTACT TYPE")
plt.ylabel("USERS")
plt.legend(['CONTACT TYPE'])
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.bar('MARITAL STATUS','PEOPLE',data=marital_df)
plt.title("BAR CHART - MARITAL STATUS")
plt.xlabel("MARITAL STATUS")
plt.ylabel("PEOPLE")
plt.legend(['MARITAL STATUS'])
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.bar('POUTCOME','STATUS',data=poutcome_df)
plt.title("BAR CHART - POUTCOME")
plt.xlabel("OUTCOME")
plt.ylabel("COUNT OF PEOPLE")
plt.legend(['POUTCOME'])
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.subplot(1,4,1)
plt.bar('JOB','COUNT',data=job_df)
plt.title("BAR CHART - COUNT OF DIFFERENT CATEGORY JOBS")
plt.xlabel("JOB NAMES")
plt.ylabel("COUNT OF PEOPLE")
plt.legend(['JOB'])
plt.show()

plt.figure(figsize=(16,6))
plt.subplot(1,4,2)
plt.bar('EDUCATION','COUNT1',data=education_df)
plt.title("BAR CHART - EDUCATION")
plt.xlabel("EDUCATION")
plt.ylabel("COUNT OF PEOPLE")
plt.legend(['EDUCATION'])
plt.show()

plt.figure(figsize=(16,6))
plt.subplot(1,4,3)
plt.bar('MARITAL STATUS','PEOPLE',data=marital_df)
plt.title("BAR CHART-MARITAL STATUS")
plt.xlabel("MARITAL STATUS ")
plt.ylabel("USERS")
plt.legend(['MARITAL STATUS'])
plt.show()

plt.figure(figsize=(16,6))
plt.subplot(1,4,4)
plt.bar('POUTCOME','STATUS',data=poutcome_df)
plt.title("BAR CHART - POUTCOME")
plt.xlabel("OUTCOME")
plt.ylabel("COUNT OF PEOPLE")
plt.legend(['POUTCOME'])
plt.show()

# %% [markdown]
# **SEA BORN BAR CHART**

# %%
plt.figure(figsize=(16,6))
sns.countplot('poutcome',data=df,hue='poutcome')
plt.title("BAR CHART - POUTCOME")
plt.xlabel("OUTCOME")
plt.ylabel("COUNT OF PEOPLE")

plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(16,6))
sns.countplot('marital',data=df,hue='marital')
plt.title("BAR CHART - MARITAL")
plt.xlabel("STATUS")
plt.ylabel("USERS")
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(34,10))
sns.countplot('education',data=df,hue='education')
plt.title("BAR CHART - EDUCATION")
plt.xlabel("EDUCATION")
plt.ylabel("COUNT OF PEOPLE")
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **HISTOGRAM**

# %%
plt.hist(df['loan'],bins=10)
plt.show()

# %%
plt.hist(df['day_of_week'],bins=10)
plt.show()

# %%
plt.hist(df['default'],bins=10)
plt.show()

# %%
plt.hist(df['housing'],bins=10)
plt.show()

# %%
plt.hist(df['month'],bins=10)
plt.show()

# %%
plt.hist(df['y'],bins=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
